# %% [markdown]
# # PROBALISTIC REASONING
# ## Name : Guruprasath M R
# ## Roll : CH.EN.U4AIE22015
# ### LAB-1

# %%
# %pip install pgmpy
# Out:
# Requirement already satisfied: pgmpy in /usr/local/python/3.10.13/lib/python3.10/site-packages (0.1.25)
# Requirement already satisfied: networkx in /home/codespace/.local/lib/python3.10/site-packages (from pgmpy) (3.3)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from pgmpy) (1.26.4)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.10/site-packages (from pgmpy) (1.13.1)
# Requirement already satisfied: scikit-learn in /home/codespace/.local/lib/python3.10/site-packages (from pgmpy) (1.5.0)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.10/site-packages (from pgmpy) (2.2.2)
# Requirement already satisfied: pyparsing in /home/codespace/.local/lib/python3.10/site-packages (from pgmpy) (3.1.2)
# Requirement already satisfied: torch in /home/codespace/.local/lib/python3.10/site-packages (from pgmpy) (2.3.0+cpu)
# Requirement already satisfied: statsmodels in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pgmpy) (0.14.2)
# Requirement already satisfied: tqdm in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pgmpy) (4.66.4)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.10/site-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: opt-einsum in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pgmpy) (3.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->pgmpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->pgmpy) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn->pgmpy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from statsmodels->pgmpy) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /home/codespace/.local/lib/python3.10/site-packages (from statsmodels->pgmpy) (24.0)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python3.10/site-packages (from torch->pgmpy) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/codespace/.local/lib/python3.10/site-packages (from torch->pgmpy) (4.12.0)
# Requirement already satisfied: sympy in /home/codespace/.local/lib/python3.10/site-packages (from torch->pgmpy) (1.12.1)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from torch->pgmpy) (3.1.4)
# Requirement already satisfied: fsspec in /home/codespace/.local/lib/python3.10/site-packages (from torch->pgmpy) (2024.5.0)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.10/site-packages (from patsy>=0.5.6->statsmodels->pgmpy) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->torch->pgmpy) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from sympy->torch->pgmpy) (1.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pgmpy.inference import VariableElimination
from pgmpy.factors.discrete import TabularCPD
from pgmpy.models import BayesianNetwork

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Creating Bayesian Network

# %%
G = BayesianNetwork()

# %% [markdown]
# Adding Nodes to the Network

# %%
G.add_nodes_from(["Burglary","Earthquake","Alarm","JohnCalls","MaryCalls"])

# %% [markdown]
# Adding Edges to the networks

# %%
G.add_edges_from([("Burglary", "Alarm"),("Earthquake","Alarm"),("Alarm","JohnCalls"),("Alarm","MaryCalls")])

# %% [markdown]
# Adding Conditonal probabilty tabel to nodes

# %%
cpd_burglary = TabularCPD(variable='Burglary', variable_card=2, values=[[0.999], [0.001]])
cpd_earthquake = TabularCPD(variable='Earthquake', variable_card=2, values=[[0.998], [0.002]])
cpd_alarm = TabularCPD(variable='Alarm', variable_card=2, 
                       values=[[0.95, 0.94, 0.29, 0.001], 
                               [0.05, 0.06, 0.71, 0.999]],
                       evidence=['Burglary', 'Earthquake'],
                       evidence_card=[2, 2])
cpd_johncalls = TabularCPD(variable='JohnCalls', variable_card=2, 
                           values=[[0.9, 0.05],
                                   [0.1, 0.95]],
                           evidence=['Alarm'],
                           evidence_card=[2])
cpd_marycalls = TabularCPD(variable='MaryCalls', variable_card=2, 
                           values=[[0.7, 0.01],
                                   [0.3, 0.99]],
                           evidence=['Alarm'],
                           evidence_card=[2])

# %%
G.add_cpds(cpd_burglary, cpd_earthquake, cpd_alarm, cpd_johncalls, cpd_marycalls)

# %%
assert G.check_model()

# %%
infer = VariableElimination(G)

# Example query
result = infer.query(variables=['JohnCalls'], evidence={'Alarm': 1})
print(result)
# Out:
# +--------------+------------------+
# | JohnCalls    |   phi(JohnCalls) |
# +==============+==================+
# | JohnCalls(0) |           0.0500 |
# +--------------+------------------+
# | JohnCalls(1) |           0.9500 |
# +--------------+------------------+
